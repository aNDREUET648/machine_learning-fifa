# %% [markdown]
# # Pràctica Fifa
#
# We want to predict the *value* of the players using the information of the player.
#
# ## Import libraries
#
# First of all we import the libraries we're gonna use.

# %%
import os

from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Ses gràfiques surten a sa mateixa pàgina en lloc d'apareixer a una altra finestra
# %matplotlib inline
# Parametritzam també com és veuran, més groses i estil ggplot
plt.style.use('ggplot')
plt.rcParams['figure.figsize']=(16,9)

# %% [markdown]
# ## Llegim es fitxer fifa.csv
#
# Llegim fifa.csv i ho carregam com un dataset ``df`` de ``pandas`` and an utility from the library
# ``os``.
#
# Visualitzam a continuació ses primeres files

# %%
df = pd.read_csv(os.path.join("..", "in", "fifa.csv"))
df.head(15)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# ...

# %% [markdown]
# ## Veïm es tamany que té

# %%
df.shape

# %% [markdown]
# ## Com a no se veuen totes ses columnes li deïm que les volem veure totes

# %%
pd.set_option('display.max_columns', None)
df.head(15)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# ...

# %% [markdown]
# # Com a ses dues primeres columnes no es aporta res de informació mos les carregam

# %%
# df = totes ses files i columnes desde sa 2 envant
df = df.iloc[:, 2:]
df
# Out:
#                      Name  Age  \
# 0                L. Messi   31
# 1       Cristiano Ronaldo   33
# 2               Neymar Jr   26
# 3                  De Gea   27
# 4            K. De Bruyne   27
# ...                   ...  ...
# 18202        J. Lundstram   19
# 18203  N. Christoffersson   19
# 18204           B. Worman   16
# 18205      D. Walker-Rice   17
# 18206           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# ...

# %% [markdown]
# # Ens carregam també columnes que no ens aportaran res de informació per s'aprenentatge

# %%
# entre cometes els camps que no vull i , axis=1 vol dir columnes, si fos files seria axis=0
df_aux=df.drop(['Photo','Flag','Club Logo','Preferred Foot','Body Type','Real Face'], axis=1)
df_aux
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage  Special  International Reputation  \
# 0             FC Barcelona  €110.5M  €565K     2202                       5.0
# ...

# %% [markdown]
# ## Tenim una columna 'Loaned From' que té valors NaN, idó ens la carregam també

# %%
df= df_aux.drop(['Loaned From'], axis=1)
df
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage  Special  International Reputation  \
# 0             FC Barcelona  €110.5M  €565K     2202                       5.0
# ...

# %% [markdown]
# ## Cercam els valors NaN del meu DataFrame ``df``

# %%
# Primer comprovam si n'hi ha
df.isnull().values.any()

# %%
# o quines columnes tenen valors NaN
df.isnull().any()

# %%
# Segon miram quants n'hi ha a cada columna
pd.set_option('display.max_columns', None)
df.isnull().sum()

# %%
# Quants hi ha en total
df.isnull().sum().sum()

# %% [markdown]
# ## Veiem quantes columnes tenen ``NaN``

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['Club',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Work Rate',
#  'Position',
#  'Jersey Number',
#  'Joined',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Marking',
#  'StandingTackle',
#  'SlidingTackle',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
# ...

# %% [markdown]
# # i quantes files

# %%
df[df.isna().any(axis=1)]
# Out:
#                 Name  Age Nationality  Overall  Potential               Club  \
# 3             De Gea   27       Spain       91         93  Manchester United
# 9           J. Oblak   25    Slovenia       90         93    Atlético Madrid
# 18     M. ter Stegen   26     Germany       89         92       FC Barcelona
# 19       T. Courtois   26     Belgium       89         90        Real Madrid
# 22          M. Neuer   32     Germany       89         89  FC Bayern München
# ...              ...  ...         ...      ...        ...                ...
# 18178   L. Wahlstedt   18      Sweden       48         65         Dalkurd FF
# 18180       M. Hurst   22    Scotland       48         58   St. Johnstone FC
# 18183  K. Pilkington   44     England       48         48   Cambridge United
# 18194       J. Milli   18       Italy       47         65              Lecce
# 18198     J. Livesey   18     England       47         70      Burton Albion
#
# ...

# %% [markdown]
# De tots aquest miram els que tenen el nom des ``'Club'`` = NaN.

# %%
df.loc[df.Club != df.Club]
# Out:
#                  Name  Age Nationality  Overall  Potential Club Value Wage  \
# 452        L. Paredes   24   Argentina       80         85  NaN    €0   €0
# 538      A. Granqvist   33      Sweden       80         80  NaN    €0   €0
# 568          A. Lunev   26      Russia       79         81  NaN    €0   €0
# 677      I. Smolnikov   29      Russia       79         79  NaN    €0   €0
# 874         A. Dzyuba   29      Russia       78         78  NaN    €0   €0
# ...               ...  ...         ...      ...        ...  ...   ...  ...
# 17197        V. Kaith   21       India       55         64  NaN    €0   €0
# 17215        K. Taimi   26     Finland       55         57  NaN    €0   €0
# 17339        S. Passi   23       India       54         63  NaN    €0   €0
# 17436  D. Lalhlimpuia   20       India       54         67  NaN    €0   €0
# 17539        C. Singh   21       India       53         62  NaN    €0   €0
#
#        Special  International Reputation  Weak Foot  Skill Moves  \
# ...

# %% [markdown]
# i ens els carregam

# %%
df = df.dropna(subset = ['Club'])
df
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage  Special  International Reputation  \
# 0             FC Barcelona  €110.5M  €565K     2202                       5.0
# ...

# %% [markdown]
# Com a no puc fer el mateix amb es ``'Release Clause'``, li canvii es nom per ``'release_clause'``

# %%
df=df.rename(columns={'Release Clause':'release_clause'})
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Position', 'Jersey Number', 'Joined',
#        'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW',
#        'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM',
#        'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
# ...

# %% [markdown]
# Ara si que puc veure els que tenen es valor ``'release_clause'`` a ``Nan``

# %%
df.loc[df.release_clause != df.release_clause]
# Out:
#                    Name  Age Nationality  Overall  Potential  \
# 28         J. Rodríguez   26    Colombia       88         89
# 38           G. Higuaín   30   Argentina       88         88
# 91             Paulinho   29      Brazil       85         85
# 166    Anderson Talisca   24      Brazil       83         90
# 176          M. Kovačić   24     Croatia       83         89
# ...                 ...  ...         ...      ...        ...
# 17979        Zhang Yuan   21    China PR       51         60
# 18026           Chen Ji   21    China PR       50         59
# 18031          Zhou Xin   20    China PR       50         61
# 18056         L. Valeau   19       Italy       50         65
# 18183     K. Pilkington   44     England       48         48
#
#                                  Club   Value   Wage  Special  \
# 28                  FC Bayern München  €69.5M  €315K     2171
# 38                              Milan    €57M  €245K     1965
# ...

# %% [markdown]
# i també m'ho carregaré

# %%
df = df.dropna(subset = ['release_clause'])
df
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage  Special  International Reputation  \
# 0             FC Barcelona  €110.5M  €565K     2202                       5.0
# ...

# %% [markdown]
# # Miram quines columnes composen els atributs del meu Data Frame ``df``

# %%
df[df.isna().any(axis=1)]
# Out:
#                 Name  Age Nationality  Overall  Potential               Club  \
# 3             De Gea   27       Spain       91         93  Manchester United
# 9           J. Oblak   25    Slovenia       90         93    Atlético Madrid
# 18     M. ter Stegen   26     Germany       89         92       FC Barcelona
# 19       T. Courtois   26     Belgium       89         90        Real Madrid
# 22          M. Neuer   32     Germany       89         89  FC Bayern München
# ...              ...  ...         ...      ...        ...                ...
# 18172     C. Hawkins   18     England       48         65      Burton Albion
# 18178   L. Wahlstedt   18      Sweden       48         65         Dalkurd FF
# 18180       M. Hurst   22    Scotland       48         58   St. Johnstone FC
# 18194       J. Milli   18       Italy       47         65              Lecce
# 18198     J. Livesey   18     England       47         70      Burton Albion
#
# ...
